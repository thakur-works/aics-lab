# %% [markdown]
# <a href="https://colab.research.google.com/github/thakur-works/aics-lab/blob/main/Copy_of_Multiple_regrreaiononAdvertisingdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('/Cellphone.csv')
df
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df, x_vars=['weight','resoloution','ppi','cpu core','cpu freq','internal mem','ram','RearCam','Front_Cam','battery'], y_vars='Price');

# %%
weightpriceplot=plt.scatter(x=df["weight"], y=df["Price"])
plt.xlabel("weight")
plt.ylabel("Price")
plt.show()
weightpriceplot=plt.scatter(df["ppi"], df["Price"])
plt.xlabel("ppi")
plt.ylabel("Price")
plt.show()
weightpriceplot=plt.scatter(df["resoloution"], df["Price"])
plt.xlabel("resoloution")
plt.ylabel("Price")
plt.show()
weightpriceplot=plt.scatter(df["cpu core"], df["Price"])
plt.xlabel("cpu core")
plt.ylabel("Price")
plt.show()
weightpriceplot=plt.scatter(df["internal mem"], df["Price"])
plt.xlabel("internal mem")
plt.ylabel("Price")
plt.show()

# %%
# x = df.drop(['Sale','Product_id','Price'],axis=1)

# %%
y = df['Price']
x=df.drop(['Price'],axis=1)

df['Price'].plot(kind = 'line')
plt.show()

# %%
from sklearn.model_selection import train_test_split
# splitting the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
print(x_train.shape)
# Out:
# (128, 11)

# %%
from sklearn.linear_model import LinearRegression
# creating an object of LinearRegression class
LR = LinearRegression()
# fitting the training data
LR.fit(x_train,y_train)
print(LR.intercept_)
print(LR.coef_)
# Out:
# 1672.2803423415119
# [ -0.86290228 -54.26649947   1.13903052  50.56008178 128.43078258
#    4.80744451 109.50557619   1.94131529   3.97363931   0.13680479
#  -71.27231423]

# %%
y_prediction =  LR.predict(x_test)
y_prediction
# Out:
# array([ 895.41673073, 1867.31472465, 2623.36964991, 1532.7260703 ,
#        1619.41566171, 1870.23412863,  895.41673073, 1346.16633271,
#        2358.2295049 , 2623.36964991, 1391.50752057, 1579.84860397,
#        1759.8863008 , 2863.70446807, 2219.43518813, 2202.49860513,
#        2487.07381494, 3047.83462591, 1466.01437563, 2202.49860513,
#        2332.61550616, 1759.8863008 , 1904.92342917, 2426.46508592,
#        3103.8397082 , 4156.80160305, 2415.38553546, 3398.02991276,
#        2675.94638535, 2502.58312412, 3047.67012643, 2566.01306215,
#        2550.31345198])

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
S=StandardScaler()
x=S.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=11,test_size=0.2)
model=LinearRegression()
model.fit(x_train,y_train)
model.score(x_test,y_test)
Model=RandomForestRegressor()
Model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
Model.score(x_test,y_test)
ypredict=Model.predict(x_test)

# %%
res=pd.DataFrame({'Actual Values':y_test,
'Predicted Values':ypredict})
res.head(10)
# Out:
#      Actual Values  Predicted Values
# 86             791            776.04
# 159           3211           3390.77
# 52            2859           2959.41
# 22            2977           2964.51
# 51            1347           1407.12
# 143           2508           2594.45
# 30            2258           2150.19
# 108           1676           1780.42
# 58            1989           2071.69
# 100           2343           2428.05

# %%
res['Actual Values'].plot(kind='kde',label='Actual Values')
res['Predicted Values'].plot(kind='kde',label='Predicted Values')
plt.legend()

# %%
# importing r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# predicting the accuracy score
score=r2_score(y_test,y_prediction)
print('r2 socre is ',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,y_prediction))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2 socre is  0.958798029509237
# mean_sqrd_error is== 23356.945098082713
# root_mean_squared error of is== 152.82979126493208

# %% [markdown]
# the Result for R^2 is 0.954 that is very good and showing that Lregression model is Right Choice.
# It means that independent variables describe 95% of dependent variable! thats Great!

# %%
import seaborn as sns
from scipy.stats import skew
# %matplotlib inline

# %%
from yellowbrick.regressor import PredictionError, ResidualsPlot
visualizer = PredictionError(LR)

visualizer.fit(x_train, y_train)  # Fit the training data to the visualizer
visualizer.score(x_test, y_test)  # Evaluate the model on the test data
visualizer.poof()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
visualizer.fit(x_train, y_train)

# %%
fig, ax = plt.subplots(4,3,figsize=(15,10))
plt.tight_layout()
l=['Sale', 'weight', 'resoloution', 'ppi', 'cpu core', 'cpu freq',
       'internal mem', 'ram', 'RearCam', 'Front_Cam', 'battery', 'thickness']
col=0
for i in range(4):
    for j in range(3):
        ax[i][j].scatter(df[l[col]],df.Price)
        ax[i][j].set_xlabel(l[col])
        if j==0:
            ax[i][j].set_ylabel('Price')
        col+=1
